# %%
import requests
import pandas as pd
from datetime import date, timedelta, datetime

# %%
BASE = "https://reports.sem-o.com/api/v1"

# %%
RESOURCE_NAMES = {
    "DA":   "MarketResult_SEM-DA_PWR-MRC-D",
    "IDA1": "MarketResult_SEM-IDA1_PWR-SEM-GB-D",
    "IDA2": "MarketResult_SEM-IDA2_PWR-SEM-GB-D",
    "IDA3": "MarketResult_SEM-IDA3_PWR-SEM-D",
}

# %%
def find_doc_id(market, delivery_day=None):
    resource = RESOURCE_NAMES[market]
    url = (
        f"{BASE}/documents/static-reports"
        f"?DPuG_ID=EA-001&page_size=500&order_by=DESC"
        f"&ExcludeDelayedPublication=0&sort_by=Date"
        f"&ResourceName={resource}"
    )
    r = requests.get(url)
    r.raise_for_status()
    docs = r.json().get("items", [])
    if not docs:
        raise ValueError(f"No documents returned for {market} ({resource})")

    for d in docs:
        auction_date = datetime.fromisoformat(d["Date"]).date()
        if market == "DA":
            #print(f'Auction date = {auction_date}')
            effective_date = auction_date + timedelta(days=1)
        else:
            effective_date = auction_date

        # If user asks for a day, try to match it
        if delivery_day and effective_date == delivery_day:
            return d["_id"]

    # If no delivery_day requested, just return the latest
    if delivery_day is None:
        d = docs[0]
        auction_date = datetime.fromisoformat(d["Date"]).date()
        effective_date = auction_date + (timedelta(days=1) if market == "DA" else timedelta(0))
        print(f"✅ Using latest {market}: delivery {effective_date} id={d['_id']}")
        return d["_id"]

    raise ValueError(f"No {market} doc found for {delivery_day}")

# %%
def fetch_prices(doc_id, market):
    url = f"{BASE}/documents/{doc_id}?IST=1"
    r = requests.get(url)
    r.raise_for_status()
    data = r.json()
    records = []
    for row in data.get("rows", []):
        if row[1][0] == "Index prices" and row[1][2] == "EUR":
            for ts, price in zip(row[2], row[3]):
                records.append({
                    "Market": market,
                    "Time": pd.to_datetime(ts),
                    "Price_EUR_MWh": float(price)
                })
    return pd.DataFrame(records)

# %%
def fetch_all(delivery_day=None):
    dfs = []
    for market in RESOURCE_NAMES:
        try:
            doc_id = find_doc_id(market, delivery_day)
            dfs.append(fetch_prices(doc_id, market))
        except Exception as e:
            print(f"⚠️ Skipping {market}: {e}")
    return pd.concat(dfs, ignore_index=True) if dfs else pd.DataFrame()

# %%
def summarise(df):
    if df.empty or "Market" not in df.columns:
        raise ValueError("Empty or invalid DataFrame for summarization.")

    # Extract delivery date from timestamp
    df["Date"] = df["Time"].dt.date

    return (
        df.groupby(["Date", "Market"])["Price_EUR_MWh"]
          .agg(
              AvgPrice="mean",
              MinPrice="min",
              MaxPrice="max"
          )
          .reset_index()
    )

# %%
if __name__ == "__main__":
    df_all = fetch_all()
    print(df_all.head())
    summary = summarise(df_all)
    print("\nDaily Summary:")
    print(summary)
# Out:
# ✅ Using latest DA: delivery 2025-08-27 id=68ac45b69620d9500d44d333
# ✅ Using latest IDA1: delivery 2025-08-25 id=68ab4c1c9620d9520a1288c6
# ✅ Using latest IDA2: delivery 2025-08-25 id=68ac18059620d9721d3ab18e
# ✅ Using latest IDA3: delivery 2025-08-24 id=68ab17609620d96706588052
#   Market                Time  Price_EUR_MWh
# 0     DA 2025-08-25 23:00:00          99.00
# 1     DA 2025-08-26 00:00:00          91.76
# 2     DA 2025-08-26 01:00:00          82.75
# 3     DA 2025-08-26 02:00:00          81.47
# 4     DA 2025-08-26 03:00:00          83.30
#
# Daily Summary:
#          Date Market    AvgPrice  MinPrice  MaxPrice
# 0  2025-08-24   IDA1  100.815000     93.15   108.480
# 1  2025-08-24   IDA3   98.356833     70.00   125.492
# 2  2025-08-25     DA   99.000000     99.00    99.000
# 3  2025-08-25   IDA1   82.848913      3.54   124.750
# 4  2025-08-25   IDA2   75.215000     11.25   124.990
# 5  2025-08-26     DA   99.542174     73.88   146.180

# %%
url = ("https://reports.sem-o.com/api/v1/documents/static-reports"
       "?DPuG_ID=EA-001&page_size=5&order_by=DESC&excludeDelayedPublication=0"
       "&sort_by=Date&ResourceName=MarketResult_SEM-DA_PWR-MRC-D")

r = requests.get(url)
print(r.status_code)
print(r.json())
# Out:
# 200
# {'pagination': {'pageSize': 5, 'currentPage': 1, 'totalItems': 363, 'totalPages': 73, 'sort_by': 'Date', 'order_by': 'DESC'}, 'resourceBaseUri': 'http://reports.sem-o.com/documents', 'items': [{'_id': '68a9a2b69620d96f921299a3', 'DPuG_ID': 'EA-001', 'ReportName': 'ETS Market Results', 'Group': ['Market Data'], 'Dynamic': True, 'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250823100000_20250823102927.csv', 'Date': '2025-08-24T10:00:00', 'DateRetention': '2025-08-23', 'PublishTime': '2025-08-25T00:00:02'}, {'_id': '68a851369620d94188524ea3', 'DPuG_ID': 'EA-001', 'ReportName': 'ETS Market Results', 'Group': ['Market Data'], 'Dynamic': True, 'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250822100000_20250822102924.csv', 'Date': '2025-08-23T10:00:00', 'DateRetention': '2025-08-22', 'PublishTime': '2025-08-24T00:00:03'}, {'_id': '68a6ffb69620d911303a8ae3', 'DPuG_ID': 'EA-001', 'ReportName': 'ETS Market Results', 'Group': ['Market Data'], 'Dynamic': True, 'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250821100000_20250821103209.csv', 'Date': '2025-08-22T10:00:00', 'DateRetention': '2025-08-21', 'PublishTime': '2025-08-23T00:00:03'}, {'_id': '68a5ae379620d962656dc813', 'DPuG_ID': 'EA-001', 'ReportName': 'ETS Market Results', 'Group': ['Market Data'], 'Dynamic': True, 'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250820100000_20250820103539.csv', 'Date': '2025-08-21T10:00:00', 'DateRetention': '2025-08-20', 'PublishTime': '2025-08-22T00:00:02'}, {'_id': '68a45cb99620d931dc6f2c9d', 'DPuG_ID': 'EA-001', 'ReportName': 'ETS Market Results', 'Group': ['Market Data'], 'Dynamic': True, 'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250819100000_20250819103142.csv', 'Date': '2025-08-20T10:00:00', 'DateRetention': '2025-08-19', 'PublishTime': '2025-08-21T00:00:02'}]}

# %%
df_all[df_all['Market']=='DA']
# Out:
#    Market                Time  Price_EUR_MWh        Date
# 0      DA 2025-08-25 23:00:00          99.00  2025-08-25
# 1      DA 2025-08-26 00:00:00          91.76  2025-08-26
# 2      DA 2025-08-26 01:00:00          82.75  2025-08-26
# 3      DA 2025-08-26 02:00:00          81.47  2025-08-26
# 4      DA 2025-08-26 03:00:00          83.30  2025-08-26
# 5      DA 2025-08-26 04:00:00          88.00  2025-08-26
# 6      DA 2025-08-26 05:00:00         101.00  2025-08-26
# 7      DA 2025-08-26 06:00:00         110.86  2025-08-26
# 8      DA 2025-08-26 07:00:00         109.09  2025-08-26
# 9      DA 2025-08-26 08:00:00         106.89  2025-08-26
# 10     DA 2025-08-26 09:00:00          92.75  2025-08-26
# 11     DA 2025-08-26 10:00:00          80.80  2025-08-26
# 12     DA 2025-08-26 11:00:00          75.03  2025-08-26
# 13     DA 2025-08-26 12:00:00          73.88  2025-08-26
# 14     DA 2025-08-26 13:00:00          73.88  2025-08-26
# 15     DA 2025-08-26 14:00:00          78.80  2025-08-26
# 16     DA 2025-08-26 15:00:00          88.05  2025-08-26
# 17     DA 2025-08-26 16:00:00          96.96  2025-08-26
# 18     DA 2025-08-26 17:00:00         106.67  2025-08-26
# 19     DA 2025-08-26 18:00:00         127.60  2025-08-26
# 20     DA 2025-08-26 19:00:00         144.98  2025-08-26
# 21     DA 2025-08-26 20:00:00         146.18  2025-08-26
# 22     DA 2025-08-26 21:00:00         139.10  2025-08-26
# 23     DA 2025-08-26 22:00:00         109.67  2025-08-26
# 24     DA 2025-08-25 23:00:00          99.00  2025-08-25
# 25     DA 2025-08-26 00:00:00          91.76  2025-08-26
# 26     DA 2025-08-26 01:00:00          82.75  2025-08-26
# 27     DA 2025-08-26 02:00:00          81.47  2025-08-26
# 28     DA 2025-08-26 03:00:00          83.30  2025-08-26
# 29     DA 2025-08-26 04:00:00          88.00  2025-08-26
# 30     DA 2025-08-26 05:00:00         101.00  2025-08-26
# 31     DA 2025-08-26 06:00:00         110.86  2025-08-26
# 32     DA 2025-08-26 07:00:00         109.09  2025-08-26
# 33     DA 2025-08-26 08:00:00         106.89  2025-08-26
# 34     DA 2025-08-26 09:00:00          92.75  2025-08-26
# 35     DA 2025-08-26 10:00:00          80.80  2025-08-26
# 36     DA 2025-08-26 11:00:00          75.03  2025-08-26
# 37     DA 2025-08-26 12:00:00          73.88  2025-08-26
# 38     DA 2025-08-26 13:00:00          73.88  2025-08-26
# 39     DA 2025-08-26 14:00:00          78.80  2025-08-26
# 40     DA 2025-08-26 15:00:00          88.05  2025-08-26
# 41     DA 2025-08-26 16:00:00          96.96  2025-08-26
# 42     DA 2025-08-26 17:00:00         106.67  2025-08-26
# 43     DA 2025-08-26 18:00:00         127.60  2025-08-26
# 44     DA 2025-08-26 19:00:00         144.98  2025-08-26
# 45     DA 2025-08-26 20:00:00         146.18  2025-08-26
# 46     DA 2025-08-26 21:00:00         139.10  2025-08-26
# 47     DA 2025-08-26 22:00:00         109.67  2025-08-26

# %%
url = "https://reports.sem-o.com/api/v1/documents/static-reports?DPuG_ID=EA-001&page_size=5&order_by=DESC&ExcludeDelayedPublication=0&sort_by=Date&ResourceName=MarketResult_SEM-DA_PWR-MRC-D"
import requests, pandas as pd
r = requests.get(url).json()
for d in r["items"]:
    print(d["Date"], "=> delivery", pd.to_datetime(d["Date"]).date() + pd.Timedelta(days=1), "publish", d["PublishTime"])
# Out:
# 2025-08-26T10:00:00 => delivery 2025-08-27 publish 2025-08-25T10:29:56
# 2025-08-25T10:00:00 => delivery 2025-08-26 publish 2025-08-24T10:30:02
# 2025-08-24T10:00:00 => delivery 2025-08-25 publish 2025-08-25T00:00:02
# 2025-08-23T10:00:00 => delivery 2025-08-24 publish 2025-08-24T00:00:03
# 2025-08-22T10:00:00 => delivery 2025-08-23 publish 2025-08-23T00:00:03

# %%
url = (
        f"{BASE}/documents/static-reports"
        f"?DPuG_ID=EA-001&page_size=500&order_by=DESC"
        f"&ExcludeDelayedPublication=0&sort_by=Date"
        f"&ResourceName=MarketResult_SEM-DA_PWR-MRC-D"
    )
r = requests.get(url)
r.raise_for_status()
docs = r.json().get("items", [])
docs
# Out:
# [{'_id': '68ac45b69620d9500d44d333',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250825100000_20250825102956.csv',
#   'Date': '2025-08-26T10:00:00',
#   'DateRetention': '2025-08-25',
#   'PublishTime': '2025-08-25T10:29:56'},
#  {'_id': '68aaf4369620d920e15095f3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250824100000_20250824103002.csv',
#   'Date': '2025-08-25T10:00:00',
#   'DateRetention': '2025-08-24',
#   'PublishTime': '2025-08-24T10:30:02'},
#  {'_id': '68a9a2b69620d96f921299a3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250823100000_20250823102927.csv',
#   'Date': '2025-08-24T10:00:00',
#   'DateRetention': '2025-08-23',
#   'PublishTime': '2025-08-25T00:00:02'},
#  {'_id': '68a851369620d94188524ea3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250822100000_20250822102924.csv',
#   'Date': '2025-08-23T10:00:00',
#   'DateRetention': '2025-08-22',
#   'PublishTime': '2025-08-24T00:00:03'},
#  {'_id': '68a6ffb69620d911303a8ae3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250821100000_20250821103209.csv',
#   'Date': '2025-08-22T10:00:00',
#   'DateRetention': '2025-08-21',
#   'PublishTime': '2025-08-23T00:00:03'},
#  {'_id': '68a5ae379620d962656dc813',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250820100000_20250820103539.csv',
#   'Date': '2025-08-21T10:00:00',
#   'DateRetention': '2025-08-20',
#   'PublishTime': '2025-08-22T00:00:02'},
#  {'_id': '68a45cb99620d931dc6f2c9d',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250819100000_20250819103142.csv',
#   'Date': '2025-08-20T10:00:00',
#   'DateRetention': '2025-08-19',
#   'PublishTime': '2025-08-21T00:00:02'},
#  {'_id': '68a30b369620d97a38711303',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250818100000_20250818103000.csv',
#   'Date': '2025-08-19T10:00:00',
#   'DateRetention': '2025-08-18',
#   'PublishTime': '2025-08-20T00:00:02'},
#  {'_id': '68a1b9b69620d94a815f3833',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250817100000_20250817103024.csv',
#   'Date': '2025-08-18T10:00:00',
#   'DateRetention': '2025-08-17',
#   'PublishTime': '2025-08-19T00:00:03'},
#  {'_id': '68a068369620d91923263ee3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250816100000_20250816102956.csv',
#   'Date': '2025-08-17T10:00:00',
#   'DateRetention': '2025-08-16',
#   'PublishTime': '2025-08-18T00:00:02'},
#  {'_id': '689f16b69620d969746a92c3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250815100000_20250815103102.csv',
#   'Date': '2025-08-16T10:00:00',
#   'DateRetention': '2025-08-15',
#   'PublishTime': '2025-08-17T00:00:03'},
#  {'_id': '689dc5379620d937db5b0977',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250814100000_20250814103039.csv',
#   'Date': '2025-08-15T10:00:00',
#   'DateRetention': '2025-08-14',
#   'PublishTime': '2025-08-16T00:00:03'},
#  {'_id': '689c73b69620d907e32c0943',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250813100000_20250813103139.csv',
#   'Date': '2025-08-14T10:00:00',
#   'DateRetention': '2025-08-13',
#   'PublishTime': '2025-08-15T00:00:03'},
#  {'_id': '689b223a9620d9573c455147',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250812100000_20250812103010.csv',
#   'Date': '2025-08-13T10:00:00',
#   'DateRetention': '2025-08-12',
#   'PublishTime': '2025-08-14T00:00:02'},
#  {'_id': '6899d0b69620d9256353ee43',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250811100000_20250811103137.csv',
#   'Date': '2025-08-12T10:00:00',
#   'DateRetention': '2025-08-11',
#   'PublishTime': '2025-08-13T00:00:03'},
#  {'_id': '68987f369620d974ad1cec83',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250810100000_20250810103117.csv',
#   'Date': '2025-08-11T10:00:00',
#   'DateRetention': '2025-08-10',
#   'PublishTime': '2025-08-12T00:00:02'},
#  {'_id': '68972db69620d9465c768fc3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250809100000_20250809103002.csv',
#   'Date': '2025-08-10T10:00:00',
#   'DateRetention': '2025-08-09',
#   'PublishTime': '2025-08-11T00:00:03'},
#  {'_id': '6895dc379620d919a34c87b3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250808100000_20250808102943.csv',
#   'Date': '2025-08-09T10:00:00',
#   'DateRetention': '2025-08-08',
#   'PublishTime': '2025-08-10T00:00:02'},
#  {'_id': '68948ab69620d96d5f01ecb3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250807100000_20250807103148.csv',
#   'Date': '2025-08-08T10:00:00',
#   'DateRetention': '2025-08-07',
#   'PublishTime': '2025-08-09T00:00:03'},
#  {'_id': '689386919620d95e4e7683ae',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250806100000_20250806103346.csv',
#   'Date': '2025-08-07T10:00:00',
#   'DateRetention': '2025-08-06',
#   'PublishTime': '2025-08-08T00:00:03'},
#  {'_id': '6891e7b79620d9168a3331f3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250805100000_20250805103111.csv',
#   'Date': '2025-08-06T10:00:00',
#   'DateRetention': '2025-08-05',
#   'PublishTime': '2025-08-07T00:00:03'},
#  {'_id': '689096379620d965500fed33',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250804100000_20250804103049.csv',
#   'Date': '2025-08-05T10:00:00',
#   'DateRetention': '2025-08-04',
#   'PublishTime': '2025-08-06T00:00:03'},
#  {'_id': '688f44b69620d93a1678aaf3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250803100000_20250803102949.csv',
#   'Date': '2025-08-04T10:00:00',
#   'DateRetention': '2025-08-03',
#   'PublishTime': '2025-08-05T00:00:03'},
#  {'_id': '688df3369620d90d906c6603',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250802100000_20250802103013.csv',
#   'Date': '2025-08-03T10:00:00',
#   'DateRetention': '2025-08-02',
#   'PublishTime': '2025-08-04T00:00:03'},
#  {'_id': '688ca8bf9620d96a1d70e054',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250801100000_20250801112001.csv',
#   'Date': '2025-08-02T10:00:00',
#   'DateRetention': '2025-08-01',
#   'PublishTime': '2025-08-03T00:00:02'},
#  {'_id': '688b50369620d92cb24c4d23',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250731100000_20250731103557.csv',
#   'Date': '2025-08-01T10:00:00',
#   'DateRetention': '2025-07-31',
#   'PublishTime': '2025-08-02T00:00:02'},
#  {'_id': '6889feba9620d979075e6bd3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250730100000_20250730103753.csv',
#   'Date': '2025-07-31T10:00:00',
#   'DateRetention': '2025-07-30',
#   'PublishTime': '2025-08-01T00:00:03'},
#  {'_id': '6888ad369620d943b5689f83',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250729100000_20250729103722.csv',
#   'Date': '2025-07-30T10:00:00',
#   'DateRetention': '2025-07-29',
#   'PublishTime': '2025-07-31T00:00:03'},
#  {'_id': '68875bb79620d90dca79b603',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250728100000_20250728103542.csv',
#   'Date': '2025-07-29T10:00:00',
#   'DateRetention': '2025-07-28',
#   'PublishTime': '2025-07-30T00:00:03'},
#  {'_id': '68860a369620d956ad0a3f33',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250727100000_20250727103012.csv',
#   'Date': '2025-07-28T10:00:00',
#   'DateRetention': '2025-07-27',
#   'PublishTime': '2025-07-29T00:00:02'},
#  {'_id': '6884b8b79620d9277b2be283',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250726100000_20250726103157.csv',
#   'Date': '2025-07-27T10:00:00',
#   'DateRetention': '2025-07-26',
#   'PublishTime': '2025-07-28T00:00:03'},
#  {'_id': '688367369620d974287f94c3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250725100000_20250725103313.csv',
#   'Date': '2025-07-26T10:00:00',
#   'DateRetention': '2025-07-25',
#   'PublishTime': '2025-07-27T00:00:03'},
#  {'_id': '688215b69620d960645bb5a3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250724100000_20250724103421.csv',
#   'Date': '2025-07-25T10:00:00',
#   'DateRetention': '2025-07-24',
#   'PublishTime': '2025-07-26T00:00:03'},
#  {'_id': '6880c4369620d97fe668f373',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250723100000_20250723103017.csv',
#   'Date': '2025-07-24T10:00:00',
#   'DateRetention': '2025-07-23',
#   'PublishTime': '2025-07-25T00:00:03'},
#  {'_id': '687f72bc9620d934e7453921',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250722100000_20250722102935.csv',
#   'Date': '2025-07-23T10:00:00',
#   'DateRetention': '2025-07-22',
#   'PublishTime': '2025-07-24T00:00:03'},
#  {'_id': '687e21369620d974f51e1ae3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250721100000_20250721103136.csv',
#   'Date': '2025-07-22T10:00:00',
#   'DateRetention': '2025-07-21',
#   'PublishTime': '2025-07-23T00:00:02'},
#  {'_id': '687ccfb69620d945196fdb33',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250720100000_20250720104027.csv',
#   'Date': '2025-07-21T10:00:00',
#   'DateRetention': '2025-07-20',
#   'PublishTime': '2025-07-22T00:00:02'},
#  {'_id': '687b7e369620d914362a3013',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250719100000_20250719103002.csv',
#   'Date': '2025-07-20T10:00:00',
#   'DateRetention': '2025-07-19',
#   'PublishTime': '2025-07-21T00:00:02'},
#  {'_id': '687a2cb69620d946ba59d4f3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250718100000_20250718103018.csv',
#   'Date': '2025-07-19T10:00:00',
#   'DateRetention': '2025-07-18',
#   'PublishTime': '2025-07-20T00:00:03'},
#  {'_id': '6878db379620d92bdc730d43',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250717100000_20250717103033.csv',
#   'Date': '2025-07-18T10:00:00',
#   'DateRetention': '2025-07-17',
#   'PublishTime': '2025-07-19T00:00:03'},
#  {'_id': '687789b79620d97956306ff3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250716100000_20250716103033.csv',
#   'Date': '2025-07-17T10:00:00',
#   'DateRetention': '2025-07-16',
#   'PublishTime': '2025-07-18T00:00:02'},
#  {'_id': '687638379620d949975f6703',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250715100000_20250715102950.csv',
#   'Date': '2025-07-16T10:00:00',
#   'DateRetention': '2025-07-15',
#   'PublishTime': '2025-07-17T00:00:03'},
#  {'_id': '6874e6b79620d91349757f73',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250714100000_20250714102949.csv',
#   'Date': '2025-07-15T10:00:00',
#   'DateRetention': '2025-07-14',
#   'PublishTime': '2025-07-16T00:00:02'},
#  {'_id': '687395369620d95ffc19ec83',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250713100000_20250713103048.csv',
#   'Date': '2025-07-14T10:00:00',
#   'DateRetention': '2025-07-13',
#   'PublishTime': '2025-07-15T00:00:03'},
#  {'_id': '687243b69620d92f0d4492c3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250712100000_20250712103030.csv',
#   'Date': '2025-07-13T10:00:00',
#   'DateRetention': '2025-07-12',
#   'PublishTime': '2025-07-14T00:00:03'},
#  {'_id': '6870f23b9620d97cbf56feb8',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250711100000_20250711103053.csv',
#   'Date': '2025-07-12T10:00:00',
#   'DateRetention': '2025-07-11',
#   'PublishTime': '2025-07-13T00:00:03'},
#  {'_id': '686fa0b79620d94ac4501213',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250710100000_20250710103450.csv',
#   'Date': '2025-07-11T10:00:00',
#   'DateRetention': '2025-07-10',
#   'PublishTime': '2025-07-12T00:00:03'},
#  {'_id': '686e4f369620d91b8b3b99a3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250709100000_20250709102959.csv',
#   'Date': '2025-07-10T10:00:00',
#   'DateRetention': '2025-07-09',
#   'PublishTime': '2025-07-11T00:00:03'},
#  {'_id': '686cfdb79620d96a843ebbb3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250708100000_20250708103143.csv',
#   'Date': '2025-07-09T10:00:00',
#   'DateRetention': '2025-07-08',
#   'PublishTime': '2025-07-10T00:00:02'},
#  {'_id': '686bac369620d932e0199ea3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250707100000_20250707103206.csv',
#   'Date': '2025-07-08T10:00:00',
#   'DateRetention': '2025-07-07',
#   'PublishTime': '2025-07-09T00:00:02'},
#  {'_id': '686a5ab69620d97f61030113',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250706100000_20250706103117.csv',
#   'Date': '2025-07-07T10:00:00',
#   'DateRetention': '2025-07-06',
#   'PublishTime': '2025-07-08T00:00:02'},
#  {'_id': '686909379620d94d95234e03',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250705100000_20250705103028.csv',
#   'Date': '2025-07-06T10:00:00',
#   'DateRetention': '2025-07-05',
#   'PublishTime': '2025-07-07T00:00:02'},
#  {'_id': '6867b7b89620d91c50201e73',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250704100000_20250704102957.csv',
#   'Date': '2025-07-05T10:00:00',
#   'DateRetention': '2025-07-04',
#   'PublishTime': '2025-07-06T00:00:02'},
#  {'_id': '686666369620d94de612fe53',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250703100000_20250703103330.csv',
#   'Date': '2025-07-04T10:00:00',
#   'DateRetention': '2025-07-03',
#   'PublishTime': '2025-07-05T00:00:03'},
#  {'_id': '686514d99620d97f8439eae3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250702100000_20250702103010.csv',
#   'Date': '2025-07-03T10:00:00',
#   'DateRetention': '2025-07-02',
#   'PublishTime': '2025-07-04T00:00:02'},
#  {'_id': '6863c33a9620d9388a703187',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250701100000_20250701103138.csv',
#   'Date': '2025-07-02T10:00:00',
#   'DateRetention': '2025-07-01',
#   'PublishTime': '2025-07-03T00:00:02'},
#  {'_id': '686271b79620d964b5071303',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250630100000_20250630103645.csv',
#   'Date': '2025-07-01T10:00:00',
#   'DateRetention': '2025-06-30',
#   'PublishTime': '2025-07-02T00:00:02'},
#  {'_id': '686120369620d931d42a9ab3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250629100000_20250629103130.csv',
#   'Date': '2025-06-30T10:00:00',
#   'DateRetention': '2025-06-29',
#   'PublishTime': '2025-07-01T00:00:02'},
#  {'_id': '685fceb69620d906800ac663',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250628100000_20250628103046.csv',
#   'Date': '2025-06-29T10:00:00',
#   'DateRetention': '2025-06-28',
#   'PublishTime': '2025-06-30T00:00:02'},
#  {'_id': '685e7d369620d910554ea027',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250627100000_20250627103112.csv',
#   'Date': '2025-06-28T10:00:00',
#   'DateRetention': '2025-06-27',
#   'PublishTime': '2025-06-29T00:00:02'},
#  {'_id': '685d2bb79620d95c722d1ae3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250626100000_20250626103118.csv',
#   'Date': '2025-06-27T10:00:00',
#   'DateRetention': '2025-06-26',
#   'PublishTime': '2025-06-28T00:00:02'},
#  {'_id': '685bda369620d97f790690f3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250625100000_20250625103102.csv',
#   'Date': '2025-06-26T10:00:00',
#   'DateRetention': '2025-06-25',
#   'PublishTime': '2025-06-27T00:00:02'},
#  {'_id': '685a88bc9620d94c1e34ada7',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250624100000_20250624103111.csv',
#   'Date': '2025-06-25T10:00:00',
#   'DateRetention': '2025-06-24',
#   'PublishTime': '2025-06-26T00:00:03'},
#  {'_id': '685937369620d917a257e863',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250623100000_20250623103243.csv',
#   'Date': '2025-06-24T10:00:00',
#   'DateRetention': '2025-06-23',
#   'PublishTime': '2025-06-25T00:00:03'},
#  {'_id': '6857e5b79620d968350e6373',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250622100000_20250622103028.csv',
#   'Date': '2025-06-23T10:00:00',
#   'DateRetention': '2025-06-22',
#   'PublishTime': '2025-06-24T00:00:03'},
#  {'_id': '685694369620d93d844ec313',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250621100000_20250621103048.csv',
#   'Date': '2025-06-22T10:00:00',
#   'DateRetention': '2025-06-21',
#   'PublishTime': '2025-06-23T00:00:02'},
#  {'_id': '685542b69620d90fcf187e93',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250620100000_20250620103201.csv',
#   'Date': '2025-06-21T10:00:00',
#   'DateRetention': '2025-06-20',
#   'PublishTime': '2025-06-22T00:00:02'},
#  {'_id': '6853f1379620d95f550dd9f3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250619100000_20250619103210.csv',
#   'Date': '2025-06-20T10:00:00',
#   'DateRetention': '2025-06-19',
#   'PublishTime': '2025-06-21T00:00:03'},
#  {'_id': '68529fb89620d93228472703',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250618100000_20250618103415.csv',
#   'Date': '2025-06-19T10:00:00',
#   'DateRetention': '2025-06-18',
#   'PublishTime': '2025-06-20T00:00:02'},
#  {'_id': '68514e389620d913b92a2173',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250617100000_20250617103132.csv',
#   'Date': '2025-06-18T10:00:00',
#   'DateRetention': '2025-06-17',
#   'PublishTime': '2025-06-19T00:00:02'},
#  {'_id': '684ffcbb9620d9607c5744c6',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250616100000_20250616103038.csv',
#   'Date': '2025-06-17T10:00:00',
#   'DateRetention': '2025-06-16',
#   'PublishTime': '2025-06-18T00:00:02'},
#  {'_id': '684eab369620d932a80ad083',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250615100000_20250615103041.csv',
#   'Date': '2025-06-16T10:00:00',
#   'DateRetention': '2025-06-15',
#   'PublishTime': '2025-06-17T00:00:03'},
#  {'_id': '684d59b69620d90504498483',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250614100000_20250614103112.csv',
#   'Date': '2025-06-15T10:00:00',
#   'DateRetention': '2025-06-14',
#   'PublishTime': '2025-06-16T00:00:02'},
#  {'_id': '684c08369620d9555939f9c3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250613100000_20250613103113.csv',
#   'Date': '2025-06-14T10:00:00',
#   'DateRetention': '2025-06-13',
#   'PublishTime': '2025-06-15T00:00:03'},
#  {'_id': '684ab6bc9620d92678462f18',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250612100000_20250612103221.csv',
#   'Date': '2025-06-13T10:00:00',
#   'DateRetention': '2025-06-12',
#   'PublishTime': '2025-06-14T00:00:02'},
#  {'_id': '684965389620d976852dc0e3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250611100000_20250611103248.csv',
#   'Date': '2025-06-12T10:00:00',
#   'DateRetention': '2025-06-11',
#   'PublishTime': '2025-06-13T00:00:02'},
#  {'_id': '684813b69620d9475f0ee663',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250610100000_20250610103140.csv',
#   'Date': '2025-06-11T10:00:00',
#   'DateRetention': '2025-06-10',
#   'PublishTime': '2025-06-12T00:00:02'},
#  {'_id': '6846c2369620d9122a3900c3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250609100000_20250609103131.csv',
#   'Date': '2025-06-10T10:00:00',
#   'DateRetention': '2025-06-09',
#   'PublishTime': '2025-06-11T00:00:03'},
#  {'_id': '684570b69620d961b71cc6a3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250608100000_20250608103110.csv',
#   'Date': '2025-06-09T10:00:00',
#   'DateRetention': '2025-06-08',
#   'PublishTime': '2025-06-10T00:00:02'},
#  {'_id': '68441f369620d9330c14e593',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250607100000_20250607103048.csv',
#   'Date': '2025-06-08T10:00:00',
#   'DateRetention': '2025-06-07',
#   'PublishTime': '2025-06-09T00:00:02'},
#  {'_id': '6842cdb69620d9041f595ba3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250606100000_20250606103051.csv',
#   'Date': '2025-06-07T10:00:00',
#   'DateRetention': '2025-06-06',
#   'PublishTime': '2025-06-08T00:00:02'},
#  {'_id': '68417c369620d9531514d133',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250605100000_20250605103231.csv',
#   'Date': '2025-06-06T10:00:00',
#   'DateRetention': '2025-06-05',
#   'PublishTime': '2025-06-07T00:00:02'},
#  {'_id': '68402ab69620d923607ee653',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250604100000_20250604103618.csv',
#   'Date': '2025-06-05T10:00:00',
#   'DateRetention': '2025-06-04',
#   'PublishTime': '2025-06-06T00:00:03'},
#  {'_id': '683ed93b9620d96e867bb117',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250603100000_20250603103138.csv',
#   'Date': '2025-06-04T10:00:00',
#   'DateRetention': '2025-06-03',
#   'PublishTime': '2025-06-05T00:00:03'},
#  {'_id': '683d87b69620d938c67c9a63',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250602100000_20250602103054.csv',
#   'Date': '2025-06-03T10:00:00',
#   'DateRetention': '2025-06-02',
#   'PublishTime': '2025-06-04T00:00:02'},
#  {'_id': '683c36369620d9082127f193',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250601100000_20250601103300.csv',
#   'Date': '2025-06-02T10:00:00',
#   'DateRetention': '2025-06-01',
#   'PublishTime': '2025-06-03T00:00:03'},
#  {'_id': '683ae4b69620d957c96ab5c3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250531100000_20250531103242.csv',
#   'Date': '2025-06-01T10:00:00',
#   'DateRetention': '2025-05-31',
#   'PublishTime': '2025-06-02T00:00:02'},
#  {'_id': '683993369620d90f7c56f4a3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250530100000_20250530103928.csv',
#   'Date': '2025-05-31T10:00:00',
#   'DateRetention': '2025-05-30',
#   'PublishTime': '2025-06-01T00:00:02'},
#  {'_id': '683841b69620d962b5394a13',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250529100000_20250529103223.csv',
#   'Date': '2025-05-30T10:00:00',
#   'DateRetention': '2025-05-29',
#   'PublishTime': '2025-05-31T00:00:02'},
#  {'_id': '6836f03c9620d9353149f583',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250528100000_20250528103222.csv',
#   'Date': '2025-05-29T10:00:00',
#   'DateRetention': '2025-05-28',
#   'PublishTime': '2025-05-30T00:00:03'},
#  {'_id': '68359eb89620d9088b782234',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250527100000_20250527103357.csv',
#   'Date': '2025-05-28T10:00:00',
#   'DateRetention': '2025-05-27',
#   'PublishTime': '2025-05-29T00:00:02'},
#  {'_id': '68344d399620d955af3011e4',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250526100000_20250526103357.csv',
#   'Date': '2025-05-27T10:00:00',
#   'DateRetention': '2025-05-26',
#   'PublishTime': '2025-05-28T00:00:02'},
#  {'_id': '6832fbb79620d92af027c913',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250525100000_20250525103305.csv',
#   'Date': '2025-05-26T10:00:00',
#   'DateRetention': '2025-05-25',
#   'PublishTime': '2025-05-27T00:00:03'},
#  {'_id': '6831aa369620d97bff3333a3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250524100000_20250524103253.csv',
#   'Date': '2025-05-25T10:00:00',
#   'DateRetention': '2025-05-24',
#   'PublishTime': '2025-05-26T00:00:02'},
#  {'_id': '683058b69620d94f3b74b9b3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250523100000_20250523103125.csv',
#   'Date': '2025-05-24T10:00:00',
#   'DateRetention': '2025-05-23',
#   'PublishTime': '2025-05-25T00:00:02'},
#  {'_id': '682f07379620d92215058273',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250522100000_20250522103107.csv',
#   'Date': '2025-05-23T10:00:00',
#   'DateRetention': '2025-05-22',
#   'PublishTime': '2025-05-24T00:00:02'},
#  {'_id': '682db5b69620d974a02e2b93',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250521100000_20250521103234.csv',
#   'Date': '2025-05-22T10:00:00',
#   'DateRetention': '2025-05-21',
#   'PublishTime': '2025-05-23T00:00:02'},
#  {'_id': '682c64379620d94a1c165e93',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250520100000_20250520103329.csv',
#   'Date': '2025-05-21T10:00:00',
#   'DateRetention': '2025-05-20',
#   'PublishTime': '2025-05-22T00:00:03'},
#  {'_id': '682b12b69620d90ecb44a053',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250519100000_20250519103305.csv',
#   'Date': '2025-05-20T10:00:00',
#   'DateRetention': '2025-05-19',
#   'PublishTime': '2025-05-21T00:00:02'},
#  {'_id': '6829c1369620d95a3968e003',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250518100000_20250518103307.csv',
#   'Date': '2025-05-19T10:00:00',
#   'DateRetention': '2025-05-18',
#   'PublishTime': '2025-05-20T00:00:02'},
#  {'_id': '68286fb69620d927713da653',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250517100000_20250517103106.csv',
#   'Date': '2025-05-18T10:00:00',
#   'DateRetention': '2025-05-17',
#   'PublishTime': '2025-05-19T00:00:02'},
#  {'_id': '68271e379620d9701d21ec83',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250516100000_20250516103154.csv',
#   'Date': '2025-05-17T10:00:00',
#   'DateRetention': '2025-05-16',
#   'PublishTime': '2025-05-18T00:00:02'},
#  {'_id': '6825ccb69620d939943f0513',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250515100000_20250515103219.csv',
#   'Date': '2025-05-16T10:00:00',
#   'DateRetention': '2025-05-15',
#   'PublishTime': '2025-05-17T00:00:03'},
#  {'_id': '68247b3b9620d9029f5b2c03',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250514100000_20250514103123.csv',
#   'Date': '2025-05-15T10:00:00',
#   'DateRetention': '2025-05-14',
#   'PublishTime': '2025-05-16T00:00:03'},
#  {'_id': '682329b89620d9380a682003',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250513100000_20250513103237.csv',
#   'Date': '2025-05-14T10:00:00',
#   'DateRetention': '2025-05-13',
#   'PublishTime': '2025-05-15T00:00:03'},
#  {'_id': '6821d83a9620d9781b49ae64',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250512100000_20250512103159.csv',
#   'Date': '2025-05-13T10:00:00',
#   'DateRetention': '2025-05-12',
#   'PublishTime': '2025-05-14T00:00:03'},
#  {'_id': '682086b69620d93ea56dea63',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250511100000_20250511103049.csv',
#   'Date': '2025-05-12T10:00:00',
#   'DateRetention': '2025-05-11',
#   'PublishTime': '2025-05-13T00:00:02'},
#  {'_id': '681f35379620d905492ca6f3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250510100000_20250510103106.csv',
#   'Date': '2025-05-11T10:00:00',
#   'DateRetention': '2025-05-10',
#   'PublishTime': '2025-05-12T00:00:02'},
#  {'_id': '681de3b69620d94ba57ca1a3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250509100000_20250509103052.csv',
#   'Date': '2025-05-10T10:00:00',
#   'DateRetention': '2025-05-09',
#   'PublishTime': '2025-05-11T00:00:02'},
#  {'_id': '681c92389620d90da6511e63',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250508100000_20250508103202.csv',
#   'Date': '2025-05-09T10:00:00',
#   'DateRetention': '2025-05-08',
#   'PublishTime': '2025-05-10T00:00:02'},
#  {'_id': '681b40b79620d94f566884c3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250507100000_20250507103254.csv',
#   'Date': '2025-05-08T10:00:00',
#   'DateRetention': '2025-05-07',
#   'PublishTime': '2025-05-09T00:00:02'},
#  {'_id': '6819ef369620d9184d3b83a3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250506100000_20250506103108.csv',
#   'Date': '2025-05-07T10:00:00',
#   'DateRetention': '2025-05-06',
#   'PublishTime': '2025-05-08T00:00:02'},
#  {'_id': '68189db69620d9581b456a43',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250505100000_20250505103230.csv',
#   'Date': '2025-05-06T10:00:00',
#   'DateRetention': '2025-05-05',
#   'PublishTime': '2025-05-07T00:00:03'},
#  {'_id': '68174c379620d92555412d23',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250504100000_20250504103049.csv',
#   'Date': '2025-05-05T10:00:00',
#   'DateRetention': '2025-05-04',
#   'PublishTime': '2025-05-06T00:00:03'},
#  {'_id': '6815fab79620d96ea53949a3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250503100000_20250503103248.csv',
#   'Date': '2025-05-04T10:00:00',
#   'DateRetention': '2025-05-03',
#   'PublishTime': '2025-05-05T00:00:03'},
#  {'_id': '6814a9389620d93ba67d8a83',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250502100000_20250502103130.csv',
#   'Date': '2025-05-03T10:00:00',
#   'DateRetention': '2025-05-02',
#   'PublishTime': '2025-05-04T00:00:03'},
#  {'_id': '681357b69620d907380b0a13',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250501100000_20250501103154.csv',
#   'Date': '2025-05-02T10:00:00',
#   'DateRetention': '2025-05-01',
#   'PublishTime': '2025-05-03T00:00:03'},
#  {'_id': '681206379620d951682c25f3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250430100000_20250430103155.csv',
#   'Date': '2025-05-01T10:00:00',
#   'DateRetention': '2025-04-30',
#   'PublishTime': '2025-05-02T00:00:03'},
#  {'_id': '6810b4b99620d91dda369bd3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250429100000_20250429103201.csv',
#   'Date': '2025-04-30T10:00:00',
#   'DateRetention': '2025-04-29',
#   'PublishTime': '2025-05-01T00:00:03'},
#  {'_id': '680f633f9620d95d672a87c8',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250428100000_20250428103235.csv',
#   'Date': '2025-04-29T10:00:00',
#   'DateRetention': '2025-04-28',
#   'PublishTime': '2025-04-30T00:00:02'},
#  {'_id': '680e18be9620d935cf5f5723',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250427100000_20250427111919.csv',
#   'Date': '2025-04-28T10:00:00',
#   'DateRetention': '2025-04-27',
#   'PublishTime': '2025-04-29T00:00:03'},
#  {'_id': '680cc0369620d972c938aef3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250426100000_20250426103158.csv',
#   'Date': '2025-04-27T10:00:00',
#   'DateRetention': '2025-04-26',
#   'PublishTime': '2025-04-28T00:00:02'},
#  {'_id': '680b6eb69620d94032536443',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250425100000_20250425104026.csv',
#   'Date': '2025-04-26T10:00:00',
#   'DateRetention': '2025-04-25',
#   'PublishTime': '2025-04-27T00:00:03'},
#  {'_id': '680a1d379620d90d7c4d7633',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250424100000_20250424103212.csv',
#   'Date': '2025-04-25T10:00:00',
#   'DateRetention': '2025-04-24',
#   'PublishTime': '2025-04-26T00:00:03'},
#  {'_id': '6808cbb89620d95c694064d3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250423100000_20250423103214.csv',
#   'Date': '2025-04-24T10:00:00',
#   'DateRetention': '2025-04-23',
#   'PublishTime': '2025-04-25T00:00:02'},
#  {'_id': '68077a439620d92b0a6fc898',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250422100000_20250422103158.csv',
#   'Date': '2025-04-23T10:00:00',
#   'DateRetention': '2025-04-22',
#   'PublishTime': '2025-04-24T00:00:03'},
#  {'_id': '680628b69620d96de76b3573',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250421100000_20250421103152.csv',
#   'Date': '2025-04-22T10:00:00',
#   'DateRetention': '2025-04-21',
#   'PublishTime': '2025-04-23T00:00:03'},
#  {'_id': '6804d7369620d94011728d13',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250420100000_20250420103105.csv',
#   'Date': '2025-04-21T10:00:00',
#   'DateRetention': '2025-04-20',
#   'PublishTime': '2025-04-22T00:00:03'},
#  {'_id': '6803974c9620d936be380ff4',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250419100000_20250419120736.csv',
#   'Date': '2025-04-20T10:00:00',
#   'DateRetention': '2025-04-19',
#   'PublishTime': '2025-04-21T00:00:04'},
#  {'_id': '680234369620d964c7216c83',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250418100000_20250418103037.csv',
#   'Date': '2025-04-19T10:00:00',
#   'DateRetention': '2025-04-18',
#   'PublishTime': '2025-04-20T00:00:03'},
#  {'_id': '6800e2b89620d9383c21f7e3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250417100000_20250417103101.csv',
#   'Date': '2025-04-18T10:00:00',
#   'DateRetention': '2025-04-17',
#   'PublishTime': '2025-04-19T00:00:03'},
#  {'_id': '67ff91379620d90a3f2eabf3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250416100000_20250416103446.csv',
#   'Date': '2025-04-17T10:00:00',
#   'DateRetention': '2025-04-16',
#   'PublishTime': '2025-04-18T00:00:03'},
#  {'_id': '67fe3fb79620d9582a0b9893',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250415100000_20250415103101.csv',
#   'Date': '2025-04-16T10:00:00',
#   'DateRetention': '2025-04-15',
#   'PublishTime': '2025-04-17T00:00:03'},
#  {'_id': '67fcee3b9620d923c10f05d3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250414100000_20250414103309.csv',
#   'Date': '2025-04-15T10:00:00',
#   'DateRetention': '2025-04-14',
#   'PublishTime': '2025-04-16T00:00:02'},
#  {'_id': '67fb9cb69620d976ff041803',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250413100000_20250413103044.csv',
#   'Date': '2025-04-14T10:00:00',
#   'DateRetention': '2025-04-13',
#   'PublishTime': '2025-04-15T00:00:03'},
#  {'_id': '67fa4b389620d94b023c2e04',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250412100000_20250412103411.csv',
#   'Date': '2025-04-13T10:00:00',
#   'DateRetention': '2025-04-12',
#   'PublishTime': '2025-04-14T00:00:03'},
#  {'_id': '67f8f9b69620d91ace053943',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250411100000_20250411103151.csv',
#   'Date': '2025-04-12T10:00:00',
#   'DateRetention': '2025-04-11',
#   'PublishTime': '2025-04-13T00:00:02'},
#  {'_id': '67f7a8389620d969c63c36a4',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250410100000_20250410103439.csv',
#   'Date': '2025-04-11T10:00:00',
#   'DateRetention': '2025-04-10',
#   'PublishTime': '2025-04-12T00:00:03'},
#  {'_id': '67f656ba9620d93b43527f34',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250409100000_20250409103519.csv',
#   'Date': '2025-04-10T10:00:00',
#   'DateRetention': '2025-04-09',
#   'PublishTime': '2025-04-11T00:00:02'},
#  {'_id': '67f505379620d90cc92ad523',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250408100000_20250408103108.csv',
#   'Date': '2025-04-09T10:00:00',
#   'DateRetention': '2025-04-08',
#   'PublishTime': '2025-04-10T00:00:03'},
#  {'_id': '67f3b3b99620d959d4608063',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20250407100000_20250407103142.csv',
#   'Date': '2025-04-08T10:00:00',
#   'DateRetention': '2025-04-07',
#   'PublishTime': '2025-04-09T00:00:03'},
#  {'_id': '67f262369620d92db07cf663',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
# ...
#   'PublishTime': '2024-10-14T00:00:03'},
#  {'_id': '670908b69620d959307c50e3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241011100000_20241011103238.csv',
#   'Date': '2024-10-12T10:00:00',
#   'DateRetention': '2024-10-11',
#   'PublishTime': '2024-10-13T00:00:03'},
#  {'_id': '6707b7369620d932264cf253',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241010100000_20241010105034.csv',
#   'Date': '2024-10-11T10:00:00',
#   'DateRetention': '2024-10-10',
#   'PublishTime': '2024-10-12T00:00:03'},
#  {'_id': '670665b69620d90e8f6d9273',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241009100000_20241009103221.csv',
#   'Date': '2024-10-10T10:00:00',
#   'DateRetention': '2024-10-09',
#   'PublishTime': '2024-10-11T00:00:02'},
#  {'_id': '670514369620d967b4643cd3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241008100000_20241008103129.csv',
#   'Date': '2024-10-09T10:00:00',
#   'DateRetention': '2024-10-08',
#   'PublishTime': '2024-10-10T00:00:03'},
#  {'_id': '6703c2b79620d9400b64ab53',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241007100000_20241007103456.csv',
#   'Date': '2024-10-08T10:00:00',
#   'DateRetention': '2024-10-07',
#   'PublishTime': '2024-10-09T00:00:02'},
#  {'_id': '670271369620d91b717e73c3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241006100000_20241006102948.csv',
#   'Date': '2024-10-07T10:00:00',
#   'DateRetention': '2024-10-06',
#   'PublishTime': '2024-10-08T00:00:03'},
#  {'_id': '67011fb69620d9761c3f9373',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241005100000_20241005102956.csv',
#   'Date': '2024-10-06T10:00:00',
#   'DateRetention': '2024-10-05',
#   'PublishTime': '2024-10-07T00:00:02'},
#  {'_id': '66ffce3a9620d9529d1625d8',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241004100000_20241004103048.csv',
#   'Date': '2024-10-05T10:00:00',
#   'DateRetention': '2024-10-04',
#   'PublishTime': '2024-10-06T00:00:03'},
#  {'_id': '66fe7cb69620d92f02577ae3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241003100000_20241003103241.csv',
#   'Date': '2024-10-04T10:00:00',
#   'DateRetention': '2024-10-03',
#   'PublishTime': '2024-10-05T00:00:02'},
#  {'_id': '66fd2b379620d90b617aa173',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241002100000_20241002103000.csv',
#   'Date': '2024-10-03T10:00:00',
#   'DateRetention': '2024-10-02',
#   'PublishTime': '2024-10-04T00:00:02'},
#  {'_id': '66fbd9b79620d961ff327653',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20241001100000_20241001103601.csv',
#   'Date': '2024-10-02T10:00:00',
#   'DateRetention': '2024-10-01',
#   'PublishTime': '2024-10-03T00:00:02'},
#  {'_id': '66fa88369620d93cce245425',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240930100000_20240930103039.csv',
#   'Date': '2024-10-01T10:00:00',
#   'DateRetention': '2024-09-30',
#   'PublishTime': '2024-10-02T00:00:03'},
#  {'_id': '66f936b69620d917087d4423',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240929100000_20240929103230.csv',
#   'Date': '2024-09-30T10:00:00',
#   'DateRetention': '2024-09-29',
#   'PublishTime': '2024-10-01T00:00:02'},
#  {'_id': '66f7e5359620d970a211f633',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240928100000_20240928103100.csv',
#   'Date': '2024-09-29T10:00:00',
#   'DateRetention': '2024-09-28',
#   'PublishTime': '2024-09-30T00:00:02'},
#  {'_id': '66f693b79620d94e4871f843',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240927100000_20240927103112.csv',
#   'Date': '2024-09-28T10:00:00',
#   'DateRetention': '2024-09-27',
#   'PublishTime': '2024-09-29T00:00:02'},
#  {'_id': '66f542369620d929ce200993',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240926100000_20240926103159.csv',
#   'Date': '2024-09-27T10:00:00',
#   'DateRetention': '2024-09-26',
#   'PublishTime': '2024-09-28T00:00:02'},
#  {'_id': '66f3f0b69620d902c6516713',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240925100000_20240925103050.csv',
#   'Date': '2024-09-26T10:00:00',
#   'DateRetention': '2024-09-25',
#   'PublishTime': '2024-09-27T00:00:04'},
#  {'_id': '66f2a2ba9620d9639e53a824',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240924100000_20240924103037.csv',
#   'Date': '2024-09-25T10:00:00',
#   'DateRetention': '2024-09-24',
#   'PublishTime': '2024-09-26T00:00:03'},
#  {'_id': '66f14db79620d933fa2a40f3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240923100000_20240923103015.csv',
#   'Date': '2024-09-24T10:00:00',
#   'DateRetention': '2024-09-23',
#   'PublishTime': '2024-09-25T00:00:02'},
#  {'_id': '66f0033e9620d91a674d8393',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240922100000_20240922102914.csv',
#   'Date': '2024-09-23T10:00:00',
#   'DateRetention': '2024-09-22',
#   'PublishTime': '2024-09-24T00:00:02'},
#  {'_id': '66eeaab69620d9641f42ed43',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240921100000_20240921102909.csv',
#   'Date': '2024-09-22T10:00:00',
#   'DateRetention': '2024-09-21',
#   'PublishTime': '2024-09-23T00:00:02'},
#  {'_id': '66ed59379620d940f75657e3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240920100000_20240920102951.csv',
#   'Date': '2024-09-21T10:00:00',
#   'DateRetention': '2024-09-20',
#   'PublishTime': '2024-09-22T00:00:03'},
#  {'_id': '66ec07b69620d916d63a1693',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240919100000_20240919102950.csv',
#   'Date': '2024-09-20T10:00:00',
#   'DateRetention': '2024-09-19',
#   'PublishTime': '2024-09-21T00:00:02'},
#  {'_id': '66eab6379620d9707d4fa183',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240918100000_20240918102901.csv',
#   'Date': '2024-09-19T10:00:00',
#   'DateRetention': '2024-09-18',
#   'PublishTime': '2024-09-20T00:00:03'},
#  {'_id': '66e964b79620d93e8b0280e3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240917100000_20240917103021.csv',
#   'Date': '2024-09-18T10:00:00',
#   'DateRetention': '2024-09-17',
#   'PublishTime': '2024-09-19T00:00:03'},
#  {'_id': '66e813379620d91428152db3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240916100000_20240916104448.csv',
#   'Date': '2024-09-17T10:00:00',
#   'DateRetention': '2024-09-16',
#   'PublishTime': '2024-09-18T00:00:03'},
#  {'_id': '66e6c1b69620d96d562c08e3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240915100000_20240915102909.csv',
#   'Date': '2024-09-16T10:00:00',
#   'DateRetention': '2024-09-15',
#   'PublishTime': '2024-09-17T00:00:03'},
#  {'_id': '66e570369620d946ee1ae333',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240914100000_20240914103005.csv',
#   'Date': '2024-09-15T10:00:00',
#   'DateRetention': '2024-09-14',
#   'PublishTime': '2024-09-16T00:00:03'},
#  {'_id': '66e41eb69620d92185431153',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240913100000_20240913102952.csv',
#   'Date': '2024-09-14T10:00:00',
#   'DateRetention': '2024-09-13',
#   'PublishTime': '2024-09-15T00:00:02'},
#  {'_id': '66e2d0bb9620d901df41f114',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240912100000_20240912102924.csv',
#   'Date': '2024-09-13T10:00:00',
#   'DateRetention': '2024-09-12',
#   'PublishTime': '2024-09-14T00:00:02'},
#  {'_id': '66e17bb79620d94afa4f3503',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240911100000_20240911102938.csv',
#   'Date': '2024-09-12T10:00:00',
#   'DateRetention': '2024-09-11',
#   'PublishTime': '2024-09-13T00:00:03'},
#  {'_id': '66e02a369620d923172f3d23',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240910100000_20240910103023.csv',
#   'Date': '2024-09-11T10:00:00',
#   'DateRetention': '2024-09-10',
#   'PublishTime': '2024-09-12T00:00:03'},
#  {'_id': '66ded8bc9620d97a9557ed68',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240909100000_20240909103056.csv',
#   'Date': '2024-09-10T10:00:00',
#   'DateRetention': '2024-09-09',
#   'PublishTime': '2024-09-11T00:00:03'},
#  {'_id': '66dd87369620d9547f710a53',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240908100000_20240908103020.csv',
#   'Date': '2024-09-09T10:00:00',
#   'DateRetention': '2024-09-08',
#   'PublishTime': '2024-09-10T00:00:03'},
#  {'_id': '66dc35b69620d92ecb60d563',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240907100000_20240907103009.csv',
#   'Date': '2024-09-08T10:00:00',
#   'DateRetention': '2024-09-07',
#   'PublishTime': '2024-09-09T00:00:02'},
#  {'_id': '66dae4379620d904b3493f73',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240906100000_20240906103017.csv',
#   'Date': '2024-09-07T10:00:00',
#   'DateRetention': '2024-09-06',
#   'PublishTime': '2024-09-08T00:00:02'},
#  {'_id': '66d992b79620d95e3b694f23',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240905100000_20240905103015.csv',
#   'Date': '2024-09-06T10:00:00',
#   'DateRetention': '2024-09-05',
#   'PublishTime': '2024-09-07T00:00:03'},
#  {'_id': '66d8413b9620d9358b21c235',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240904100000_20240904103022.csv',
#   'Date': '2024-09-05T10:00:00',
#   'DateRetention': '2024-09-04',
#   'PublishTime': '2024-09-06T00:00:03'},
#  {'_id': '66d6efb69620d90d56367643',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240903100000_20240903103030.csv',
#   'Date': '2024-09-04T10:00:00',
#   'DateRetention': '2024-09-03',
#   'PublishTime': '2024-09-05T00:00:03'},
#  {'_id': '66d59e369620d964036bcc43',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240902100000_20240902103213.csv',
#   'Date': '2024-09-03T10:00:00',
#   'DateRetention': '2024-09-02',
#   'PublishTime': '2024-09-04T00:00:03'},
#  {'_id': '66d44cb69620d93f104791e3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240901100000_20240901103059.csv',
#   'Date': '2024-09-02T10:00:00',
#   'DateRetention': '2024-09-01',
#   'PublishTime': '2024-09-03T00:00:02'},
#  {'_id': '66d2fb369620d91a9c3c4c03',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240831100000_20240831103135.csv',
#   'Date': '2024-09-01T10:00:00',
#   'DateRetention': '2024-08-31',
#   'PublishTime': '2024-09-02T00:00:02'},
#  {'_id': '66d1a9b69620d973f146bd43',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240830100000_20240830103324.csv',
#   'Date': '2024-08-31T10:00:00',
#   'DateRetention': '2024-08-30',
#   'PublishTime': '2024-09-01T00:00:03'},
#  {'_id': '66d058379620d94a2f65c6f7',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240829100000_20240829103246.csv',
#   'Date': '2024-08-30T10:00:00',
#   'DateRetention': '2024-08-29',
#   'PublishTime': '2024-08-31T00:00:03'},
#  {'_id': '66cf06b99620d924645f61c4',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240828100000_20240828103108.csv',
#   'Date': '2024-08-29T10:00:00',
#   'DateRetention': '2024-08-28',
#   'PublishTime': '2024-08-30T00:00:02'},
#  {'_id': '66cdb5399620d97c661593c4',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240827100000_20240827103213.csv',
#   'Date': '2024-08-28T10:00:00',
#   'DateRetention': '2024-08-27',
#   'PublishTime': '2024-08-29T00:00:03'},
#  {'_id': '66cc63b69620d953473be8a3',
#   'DPuG_ID': 'EA-001',
#   'ReportName': 'ETS Market Results',
#   'Group': ['Market Data'],
#   'Dynamic': True,
#   'ResourceName': 'MarketResult_SEM-DA_PWR-MRC-D+1_20240826100000_20240826103222.csv',
#   'Date': '2024-08-27T10:00:00',
#   'DateRetention': '2024-08-26',
#   'PublishTime': '2024-08-28T00:00:02'}]
